# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
#Calling out the data
dt=pd.read_csv('adult-all.csv')
dt
# Out:
#        Age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64                 ?  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
#converting the unknown values to NA
dt.replace('?', pd.NA, inplace=True)
for column in dt.columns:
     mode_val = dt[column].mode()[0]
dt[column].fillna(mode_val, inplace=True)
dt
# Out:
#        Age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64              <NA>  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
#dropping the rows that include null values
dt.dropna(subset=['workclass'],inplace=True)
dt.dropna(subset=['occupation'],inplace=True)
dt.dropna(subset=['native-country'],inplace=True)
dt
# Out:
#        Age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48836   33           Private  245211  Bachelors             13
# 48837   39           Private  215419  Bachelors             13
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
dt.isnull().sum()
# Out:
# Age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
dt.describe()
# Out:
#                 Age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  45222.000000  4.522200e+04   45222.000000  45222.000000  45222.000000
# mean      38.547941  1.897347e+05      10.118460   1101.430344     88.595418
# std       13.217870  1.056392e+05       2.552881   7506.430084    404.956092
# min       17.000000  1.349200e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.173882e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783160e+05      10.000000      0.000000      0.000000
# 75%       47.000000  2.379260e+05      13.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    45222.000000
# mean        40.938017
# std         12.007508
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#importing visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
sns.countplot(x='native-country', hue='income', data=dt)
plt.xticks(rotation=90)
plt.title('Count of native country by income')
plt.show()

# %%
#comparing variables
sns.set_style("white")
sns.scatterplot(x='Age', y='hours-per-week', hue='income', data=dt,marker='*')
plt.xticks(rotation=90)
plt.title('Age vs Hours')
plt.show()

# %%
#comparing variables
sns.set_style("white")
sns.scatterplot(x='Age', y='hours-per-week', hue='sex', data=dt,marker='.')
plt.xticks(rotation=90)
plt.title('Age vs hours-per-week,male;female')
plt.show()

# %%
#comparing variables
sns.set_style("white")
sns.scatterplot(x='capital-gain', y='hours-per-week', hue='income', data=dt,marker='.')
plt.xticks(rotation=90)
plt.title('Capital gain impact on income')
plt.show()

# %%
#comparing variables
sns.set_style("white")
sns.scatterplot(x='capital-loss', y='hours-per-week', hue='income', data=dt,marker='.')
plt.xticks(rotation=90)
plt.title('Capital loss impact on income')
plt.show()

# %%
#comparing variables
sns.set_style("darkgrid")
sns.countplot(x='marital-status', hue='income', data=dt)
plt.xticks(rotation=45)
plt.title('marital-status impact on income')
plt.show()

# %%
#comparing variables
sns.set_style("darkgrid")
sns.countplot(x='education', hue='income', data=dt)
plt.xticks(rotation=90)
plt.title('education-status vs income')
plt.show()

# %%
#comparing variables
sns.set_style("darkgrid")
sns.countplot(x='workclass', hue='income', data=dt)
plt.xticks(rotation=90)
plt.title('education-status vs income')
plt.show()

# %%
#comparing variables
sns.set_style("darkgrid")
sns.countplot(x='occupation', hue='income', data=dt)
plt.xticks(rotation=90)
plt.title('occupation vs income')
plt.show()

# %%
#grouping column into categories
ranges_age = [(0, 20), (21, 40), (41, 60), (61, 80), (81, 100)]
categories_age = [' Young', 'Adult', 'Mid-Age', 'Retired', 'Old']
dt['age_category'] = pd.cut(dt['Age'], bins=[range[0] - 0.5 for range in ranges_age] + [max(range[1] for range in ranges_age) + 0.5], labels=categories_age)
ranges_hours = [(0, 40), (40, 60), (60, 80), (80,100)]
categories_hours = ['Normal', 'Hardwork', 'Extra-HardWork', 'Over-the-limit']
dt['hours_category'] = pd.cut(dt['hours-per-week'], bins=[range[0] - 0.5 for range in ranges_hours] + [max(range[1] for range in ranges_hours) + 0.5], labels=categories_hours)

# %%
dt
# Out:
#        Age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48836   33           Private  245211  Bachelors             13
# 48837   39           Private  215419  Bachelors             13
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
features=['Age','workclass','fnlwgt','sex','capital-gain','capital-loss','hours-per-week']
target=['income']

# %%
#Capital-gain categorization
bins = [0, 5000, 10000, 15000, 20000, float('inf')]
labels = ['Low', 'Medium', 'High', 'Very High', 'Extremely High']
dt['capital-gain_category'] = pd.cut(dt['capital-gain'], bins=bins, labels=labels, right=False)
#Capital-loss categorization
bins = [0, 1000, 2000, 3000, 4000, float('inf')]
labels = ['Low', 'Medium', 'High', 'Very High', 'Extremely High']
dt['capital-loss_category'] = pd.cut(dt['capital-loss'], bins=bins, labels=labels, right=False)
#finalwgt categorization
bins = [0, 50000, 100000, 150000, 200000, float('inf')]
labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
dt['fnlwgt_category'] = pd.cut(dt['fnlwgt'], bins=bins, labels=labels, right=False)

# %%
dt
# Out:
#        Age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48836   33           Private  245211  Bachelors             13
# 48837   39           Private  215419  Bachelors             13
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
#encoding
from sklearn.preprocessing import LabelEncoder
categorical_columns = ['capital-gain_category','capital-loss_category','fnlwgt_category', 'education-num', 'sex', 'age_category','hours_category','income','workclass']
label_encoder = LabelEncoder()
for col in categorical_columns:
    dt[col + '_encoded'] = label_encoder.fit_transform(dt[col])

# %%
dt
# Out:
#        Age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48836   33           Private  245211  Bachelors             13
# 48837   39           Private  215419  Bachelors             13
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation   relationship  \
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
#KNN model
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
X = dt[['capital-gain_category_encoded','capital-loss_category_encoded','fnlwgt_category_encoded', 'education-num_encoded', 'sex_encoded', 'age_category_encoded','hours_category_encoded','workclass_encoded']]
y = dt['income_encoded']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

knn = KNeighborsClassifier(n_neighbors=15)  

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8104960566079458

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
y_pred=knn.predict(X_test)

cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[9595  598]
#  [1973 1401]]

# %%
#Heatmap
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(7,5))
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(60.222222222222214, 0.5, 'Truth')

# %%
#Classification Report
from sklearn.metrics import classification_report

cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88     10193
#            1       0.70      0.42      0.52      3374
#
#     accuracy                           0.81     13567
#    macro avg       0.77      0.68      0.70     13567
# weighted avg       0.80      0.81      0.79     13567

# %%
#trying out alternative methods to check the effect on accuracy
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


knn_hamming = KNeighborsClassifier(n_neighbors=15, metric='hamming')
knn_manhattan = KNeighborsClassifier(n_neighbors=15, metric='manhattan')
knn_minkowski = KNeighborsClassifier(n_neighbors=15, metric='minkowski', p=2)  


knn_hamming.fit(X_train, y_train)
knn_manhattan.fit(X_train, y_train)
knn_minkowski.fit(X_train, y_train)

y_pred_hamming = knn_hamming.predict(X_test)
y_pred_manhattan = knn_manhattan.predict(X_test)
y_pred_minkowski = knn_minkowski.predict(X_test)

print("Classification Report - Hamming Distance:")
print(classification_report(y_test, y_pred_hamming))

print("Classification Report - Manhattan Distance:")
print(classification_report(y_test, y_pred_manhattan))

print("Classification Report - Minkowski Distance (Euclidean):")
print(classification_report(y_test, y_pred_minkowski))
# Out:
# Classification Report - Hamming Distance:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84     10193
#            1       0.49      0.33      0.39      3374
#
#     accuracy                           0.75     13567
#    macro avg       0.64      0.61      0.62     13567
# weighted avg       0.72      0.75      0.73     13567
#
# Classification Report - Manhattan Distance:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84     10193
#            1       0.49      0.33      0.39      3374
#
#     accuracy                           0.75     13567
#    macro avg       0.64      0.61      0.62     13567
# weighted avg       0.72      0.75      0.73     13567
#
# Classification Report - Minkowski Distance (Euclidean):
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84     10193
# ...
